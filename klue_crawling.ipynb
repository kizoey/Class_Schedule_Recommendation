# %%
# !pip3 install selenium
# Out:
# ...
#      |████████████████████████████████| 904 kB 65 kB/s eta 0:00:011
# ...

# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
import time
import sys
import requests

# %%
url = "https://klue.kr/login"

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument("--single-process")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome('/Users/zoeyki/Downloads/chromedriver', options=options)

delay_time = 3
driver.implicitly_wait(delay_time)

driver.get(url)

# %%
id = "gy2019150412"
pwd = "gy2019150412!"

# %%
#아이디, 비밀번호 접근
input_id = driver.find_element_by_xpath("/html/body/div/div/div/div/div/div/input[1]")
input_id.send_keys(id)

input_pwd = driver.find_element_by_xpath("/html/body/div/div/div/div/div/div/input[2]")
input_pwd.send_keys(pwd)

# %%
#로그인 버튼 클릭
login = driver.find_element_by_xpath("/html/body/div/div/div/div/div/div/button")
login.click()

# %%
urls = [
"https://klue.kr/lectures/105869",
"https://klue.kr/lectures/105870",
"https://klue.kr/lectures/105871",
"https://klue.kr/lectures/105872",
"https://klue.kr/lectures/105873",
"https://klue.kr/lectures/105874",
"https://klue.kr/lectures/105875",
"https://klue.kr/lectures/105876",
"https://klue.kr/lectures/105877",
"https://klue.kr/lectures/105878",
"https://klue.kr/lectures/105879",
"https://klue.kr/lectures/105880",
"https://klue.kr/lectures/105881",
"https://klue.kr/lectures/105882",
"https://klue.kr/lectures/105883",
"https://klue.kr/lectures/105884",
"https://klue.kr/lectures/105885",
"https://klue.kr/lectures/105886",
"https://klue.kr/lectures/105887",
"https://klue.kr/lectures/105888",
"https://klue.kr/lectures/105889",
"https://klue.kr/lectures/105890",
"https://klue.kr/lectures/105891",
"https://klue.kr/lectures/105892",
"https://klue.kr/lectures/105893",
"https://klue.kr/lectures/107747",
"https://klue.kr/lectures/107748",
"https://klue.kr/lectures/107749",
"https://klue.kr/lectures/107750",
"https://klue.kr/lectures/107751",
"https://klue.kr/lectures/107752",
"https://klue.kr/lectures/107753",
"https://klue.kr/lectures/107754",
"https://klue.kr/lectures/107755",
"https://klue.kr/lectures/107756",
"https://klue.kr/lectures/107757",
"https://klue.kr/lectures/107758",
"https://klue.kr/lectures/107759",
"https://klue.kr/lectures/107760",
"https://klue.kr/lectures/107761",
"https://klue.kr/lectures/107762",
"https://klue.kr/lectures/107763",
"https://klue.kr/lectures/107764",
"https://klue.kr/lectures/107828",
"https://klue.kr/lectures/107829",
"https://klue.kr/lectures/107830",
"https://klue.kr/lectures/107831",
"https://klue.kr/lectures/107832",
"https://klue.kr/lectures/107833",
"https://klue.kr/lectures/107834",
"https://klue.kr/lectures/107835",
"https://klue.kr/lectures/107836",
"https://klue.kr/lectures/107837",
"https://klue.kr/lectures/107838",
"https://klue.kr/lectures/107839",
"https://klue.kr/lectures/107840",
"https://klue.kr/lectures/107841",
"https://klue.kr/lectures/107842",
"https://klue.kr/lectures/107843",
"https://klue.kr/lectures/107844",
"https://klue.kr/lectures/107845",
"https://klue.kr/lectures/107846",
"https://klue.kr/lectures/108102",
"https://klue.kr/lectures/108103",
"https://klue.kr/lectures/108104",
"https://klue.kr/lectures/108105",
"https://klue.kr/lectures/108106",
"https://klue.kr/lectures/108107",
"https://klue.kr/lectures/108108",
"https://klue.kr/lectures/108109",
"https://klue.kr/lectures/108110",
"https://klue.kr/lectures/108111",
"https://klue.kr/lectures/108112",
"https://klue.kr/lectures/108113",
"https://klue.kr/lectures/108710",
"https://klue.kr/lectures/108711",
"https://klue.kr/lectures/108712",
"https://klue.kr/lectures/108713",
"https://klue.kr/lectures/108714" #서양음악의 과학적 이해
]

# %%
#크롤링된 내용 저장할 workbook 생성
import urllib.response, requests
import openpyxl

try:
    wb = openpyxl.load_workbook("klue_score_final_zoey.xlsx")
    sheet = wb.active

except:  # try에서 error 발생하면
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.append(["class_name", "professor_name", "work_load", "level", "teaching", "proud"])

# %%
#강의명/교수명/강의평 데이터 크롤링 (workbook에 저장)
for i in range(len(urls)):
    try:
        driver.get(urls[i])
        info = driver.find_elements_by_xpath("/html/body/div/div/div/section[1]/div/div[1]/div[1]/div[2]")

        for n in info:
            try:
                class_name = n.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[1]/div[1]/div[2]/p[1]")
                professor_name = n.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[1]/div[1]/div[2]/p[2]/span[1]")
            except:
                class_name = "NULL"
                professor_name = "NULL"


        #강의 평가 컨테이너 데이터 수집
        evals = driver.find_elements_by_xpath("/html/body/div/div/div/section[1]/div/div[3]/div/div[1]/div[3]")
        for e in evals:

            #학습량
            try:
                work_load = e.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[3]/div/div[1]/div[3]/div[1]/div[1]/div[1]/span[2]")
            except:
                work_load = "NULL"

            #난이도
            try:
                level = e.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[3]/div/div[1]/div[3]/div[1]/div[2]/div[1]/span[2]")
            except:
                level = "NULL"

            #강의력
            try:
                teaching = e.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[3]/div/div[1]/div[3]/div[2]/div[1]/div[1]/span[2]")
            except:
                teaching = "NULL"

            #성취감
            try:
                proud = e.find_element_by_xpath("/html/body/div/div/div/section[1]/div/div[3]/div/div[1]/div[3]/div[2]/div[2]/div[1]/span[2]")
            except:
                proud = "NULL"        
            
        sheet.append([class_name.text, professor_name.text, work_load.text, level.text, teaching.text, proud.text])
        print('pass')
    except:
        print('error')

print('download complete')
wb.save("klue_score_final_zoey.xlsx")
# Out:
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# error
# error
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# error
# pass
# pass
# pass
# pass
# pass
# error
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# error
# download complete

# %%
#강의평 데이터는 순환문이 달라 따로 저장
try:
    wb = openpyxl.load_workbook("klue_evaluation_final_zoey.xlsx")
    sheet = wb.active

except:  # try에서 error 발생하면
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.append(["evaluation"])


for i in range(len(urls)): #중간에 끊기면 앞에 번호-1로 시작(4번째까지 완료되면 4번 시작~)
    try:
        driver.get(urls[i])
        eval_list = []
        for n in range(1, 50):
            try:
                container = driver.find_elements_by_xpath("/html/body/div/div/div/section[3]/div/div/div[2]/div/div[%d]" % n)
                for c in container:
                    evaluation = c.find_element_by_xpath("/html/body/div/div/div/section[3]/div/div/div[2]/div/div[%d]/p" % n)
                    eval_list.append(evaluation.text)
                    n += 1  
            except:
                break
        eval_list = "".join(eval_list)
        sheet.append([eval_list])
        print('pass')
    except:
        print('error')

print('download complete')
wb.save("klue_evaluation_final_zoey.xlsx")
# Out:
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# error
# download complete

# %%
#점수/강의평 데이터 합쳐주기
import pandas as pd

klue_score = pd.read_excel("klue_score_final_zoey.xlsx")
klue_eval = pd.read_excel("klue_evaluation_final_zoey.xlsx")
klue = pd.concat([klue_score, klue_eval], axis=1)
klue.head(50)
# Out:
#                                            class_name   professor_name  \
# 0                                         데이터네트워크(영강)              김중헌
# 1                                               디지털통신              김운경
# 2                                               디지털통신              이인규
# 3                                               디지털통신               허준
# 4                                          반도체공학Ⅱ(영강)              유현용
# 5                                            운영체제(영강)              곽진태
# 6                                               전력공학Ⅱ              이병준
# 7                                           전기기기Ⅰ(영강)              이상빈
# 8                                             디지털신호처리              고성제
# 9                                             디지털신호처리              설상훈
# 10                                            디지털신호처리              김종옥
# 11                                               제어공학              임묘택
# ...

# %%
klue.to_csv("klue_crawling_dayeon.csv")
